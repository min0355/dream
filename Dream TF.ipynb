# %% [markdown]
# # 구글의 문샷 팩토리
#
# ## 아무도 해결하지 못한 기존의 문제에 초점
# ## 전례 없는 기술을 개발하여 해결
#
# ### 통상적인 업무와 다르고 혁신을 위한 업무 팀
#
# * 실패를 축하
# * 제일 어려운 부분부터 하고 빨리 망하자. (비용 낭비 방지)
#     - 실패의 경험을 조직의 자산으로 고려
#     - 책임을 절대 묻지 않음.
#     - 팀 해체 후 전원 보너스 지급

# %% [markdown]
# ## 혁신 팀
# * 웨이모 (자율 주행 전문 기업)
# * 윙 (자율 주행 드론 기업)
# * 칼리코 (머신 러닝을 활용한 생명공학) : 사명은 "사람을 죽지 않게 만든다."

# %% [markdown]
# # 그러니까, 우리 TFT 의 목표는 무엇이고 실패에 대한 생각을 어떻게 가져야 할 것인가?

# %% [markdown]
# ## 마인드 짱 (21 세기는 심적 수양이 지배할 것.)

# %% [markdown]
# ## 전체 매출액 규모
#
# #### 보고서 558 만원 헉...
# https://www.giikorea.co.kr/report/go958571-robotic-fruit-picker.html
#
# 1. 세계 과일 수확 로봇 시장 규모 (20 ~ 27 년)
#     - 연 평균 6.3 % CAGR
#     - 151.8 M 달러 (20 년, 1,700 억) ~ 227,9 M 달러 (27 년, 2,550 억)
#     - 과일 수확 매출액에 비하면 시장 초기 형성 단계의 사업
#     - 10 % 의 시장 점유율을 목표로 한다면 (미국 30 % M/S, 중국 M/S 성장 중)
#     - **25 년도에 기대 할 수 있는 현실적 수준 : 20.6 M 달러 (230 억) 수준을 목표로 매출액과 사업 범위를 넓혀가는 계획**
#     - 개발 기간 3 년 (초기 시장 선점)
#         1. H/W 개발
#             1) 매우 저가형 (Puma-Exbana) : 목표 제조가 70 불 (판매가 100 불, 11.2 만, 30 % Margin) => 연봉 5,832 만원 기준 약 263 만원을 직원에 투자하는 꼴
#                 * 목표 수출 국가 : 근로자 연 수익 2,000 불 초반 (인도, 베트남 : 2,086 ~ 2,349 불 / 년)
#                 * 상황 : 소매상들이 바나나의 도매가를 대폭 깎기 때문에 농장 주인은 매우 낮은 임금을 줄 수 밖에 없는 형국 (바나나 링크, 자선 단체)
#                 * 관련 과일 : 바나나, 망고, 레몬, 파파야, 수박, 자몽
#                 * 과일 가격 (alibaba.com)
#                             - 바나나 : **150 ~ 900 불 / 톤** (뭉치 하나당 15 kg 추정 시 약 67 뭉치, **뭉치당 2,580 ~ 15,500 원**)
#                                       => 7 ~ 44 뭉치만 옮기면 구매가 수준의 매출액 달성 (미국 수출 기준)
#                                       => 위는 alibaba 소매가로 미국 소비 기준이며, 95 % 자국 내 소비하는 인도의 경우 총 2,622 만 톤 정도가 내수 총량
#                                       => 1 묶음 (kg) 당 500 원 (30 바트) 수준인 인도 내수 소비가로 계산 시 8.7 조원 (인도만)
#                                       => 대략 인도에서만 17.6 억 개의 바나나 뭉치를 연간 수확해야 함. (한 뭉치 평균 75 개 바나나 가정, 50 ~ 100 개)
#                                       => 보다 적은 노동 인력으로 목표 수확량을 동일하게 채우면서 농장주에게 비용 절감을 이루어 낼 수 있는가 관점 필요
#                                           사례 1) 100 명의 인도인 노동자 : 총액 208,600 불 (2.33 억)
#                                           사례 2) 80 명의 인도인 노동자 + 80 개의 Puma-Exbana : 년간 33,720 불 절감 (3,770 만원)
#
#                             - 망고, 레몬, 파파야, 수박, 자몽도 동일한 논리로
#
#                 * 개발 컨셉 : 과일 수확 방법에 따른 분류 개발 (예를 들면 Exbana 은 바나나 수확기, Exmang 은 망고 수확기 등)
#                 * 개발 기간 : 1 년 이내 (시제품 설계 - 제작 - 검증 - 시제 보완 - 론칭)
#                 * 개발 성능 : 20 % 노동력 증대
#                 * 특허권 : 주요 판매국 해외 특허 출원
#                 * 장애 요인 :
#                             1) 무 동력 device 는 기술 침해 우려가 매우 높고 현지 Copy 품 성행 우려 높음.
#                             2) 너무 값싼 노동력을 사용함으로 노동 인권 처우 개선 및 노동력 증대에 구매자들이 지갑을 열지 않을 가능성
#                             3) 수출 장벽 (행정적 규제, 산업 device 라 엄밀한 잣대를 들어 대긴 어려우나 자국 산업 보호 주의 발동 시?)
#                             4) 농장 주인들이 어떻게 이 제품을 인지하게 할 것 인지 적합한 마케팅 수단 (판매는 온라인 구매 / 배송 등을 활용 가능)
#             2)
#
#             * 선정 과일에 대한 수확 기계 설계 (QCD)
#                 1) Quality : 장기간 수확 가능 내구성을 갖춘 수확
#             *
#     - 기술 개발 후 매각 조치도 가능 (대표적 성공 사례, 유튜브 등)
#     -

# %% [markdown]
# #### 로봇 참고 동영상
#
# https://www.youtube.com/watch?v=FxuVzVJ_xRE

# %%
import pandas as pd
pd.set_option('max_columns', None)
import numpy as np

# %%
df = pd.read_csv(r'E:\ML\dream\fruit.csv', encoding='cp949', parse_dates=True)
df
# Out:
#       종류     백만톤    년도  크기  모양   무게 채집 손상도 열매 위치  채집 방식 최다 생산국 2 등 생산국  \
# 0    토마토  180.80  2019  작다  동글  가볍다    낮음      하      6     중국      인도
# 1    바나나  153.10  2017  보통  길다  무겁다     낮음     상      3     인도      중국
# 2     수박  100.40  2019  크다  동글  무겁다     낮음     하      4     중국      터키
# 3     사과   86.10  2018  작다  동글  가볍다     높음     상      1     중국      미국
# 4    오렌지   78.70  2019  작다  동글  가볍다     낮음     상      2    브라질      중국
# 5     포도   67.00  2012  보통  길다  가볍다     높음     상      5     중국      미국
# 6     망고   55.90  2019  보통  동글  가볍다     낮음     상      2     인도   인도네시아
# 7      귤   34.40  2018  작다  동글  가볍다     낮음     상      2     중국     스페인
# 8   파인애플   28.20  2019  크다  길다  무겁다     낮음     하      4  코스타리카     필리핀
# 9     멜론   27.40  2018  크다  동글  무겁다     낮음     하      4     중국      터키
# 10   복숭아   24.40  2018  작다  동글  가볍다     높음     상      1     중국     이태리
# 11     배   23.70  2018  보통  동글  가볍다     낮음     상      2     중국      미국
# ...

# %% [markdown]
#
# 1. 마케팅팀 시장조사/분석
# 1) 과일/채소 조별로 마케팅팀 시장조사/분석 요청 내용 정리
# Ex) 현재 로봇/자동화 시장의 농기계분야 점유율, 상품라인업 등
# 2) 이수지 대리 취합 (~6/2,수) 하여 유종원 과장님께 요청 à 차월 미팅(6월 중순) 공유
#
# 2. 5월 LP활동 아디디어 공유 (지침사항)
# 1) 사업성 관점에서 좀 더 고민해볼 것 (w/ 논리적 배경)
# - 과일 kg당 가격 (단가)를 확인해볼 것
# (ex) 인건비 투입이 적은 것, 단순 생산량으로 보지 말것)
# - 사업성에 규모(비용)가 따라야 하므로, 수익성이 높은 것으로 검토 필요
# - 과제 최종 Goal은 사업성, 기술방향성을 검토 (시제작이 목표가 아님)
# 비용 산정이 어렵다면 판매가가 가정 하에 원가를 맞추는 등 논리를 세우는 것이 필요
#
# 2) 다방면 관점으로 조사해볼 것
# - 1년 내 소비가 되는 것, 수확 후 활용이 가능한 것, 친환경 여부 등
# (ex)포도 à 포도주로 들어가는 양, 과일 주스용 등)
#
# 3) 공정과정에서의 자동화 검토해 볼 것
# - 농기계만 개발할 것이 아니라, 수확 외 공정 과정에서의 아이디어도 고민 필요

# %% [markdown]
# ## 3 가지 형태의 Exoskeleton
#
#     1. 두 팔이 어깨 위로 올라가는 동작 보조 (바나나 등)
#     2. 수평 동작 보조 (오렌지 등)
#     2. 허리를 숙였다 펴는 동작 보조 (수박 등)

# %% [markdown]
# ### 팔아 먹어야 하는 나라 (중국, 인도, 브라질, 코스타리카) 를 고려하면 비 전동식이 좀 더 가격 우위에 있음.

# %% [markdown]
# ## 100 불로 만드는 exo (potentiometer, battery)
#
# https://www.open-electronics.org/exoarm-a-100-arduino-powered-exoskeleton-arm/
#
# ![](https://i2.wp.com/www.open-electronics.org/wp-content/uploads/2017/07/arduexo.jpg?resize=768%2C576&ssl=1)

# %% [markdown]
# ## 바나나 채집 동작
#
# * 바나나 뭉치 : 12 ~ 15 kg 추정
#
# 1. 바나나 주변 가지 치기 (위치 : 상) (시간 : 3) (부하 : 1)
# 2. 바나나 뭉치 당기기 (위치 : 하) (시간 : 1) (부하 : 2)
# 3. 비닐 벗기기 (위치 : 상) (시간 : 1) (부하 : 1)
# 4. 바나나 사이 손상 방지 처리 (위치 : 중) (시간 : 1) (부하 : 1)
# 5. 자르기 (위치 : 상) (시간 : 1) (부하 : 1)
# 6. 바나나 뭉치 이동 / 컨베이어 걸기 (위치 : 상) (시간 : 3) (부하 : 3)
#
# * Total
#     - **상 : 시간 8, 부하 6**
#     - 중 : 시간 1, 부하 1
#     - 하 : 시간 1, 부하 2

# %% [markdown]
# # 바나나 채집 exo 고려 특징
# * 접근성 나쁨 고려 : 하반신 미 장착
# * 바닥 진흙, 운동 부하 있음 : 하반신 미 장착 (다리용 exo 결합 가능)
# * 산업용은 별도 인허가 불 필요 : 과일 수확
# * **동력 불 필요** : 다량 판매를 위해 매우 중요한 조건
# * 경량화 : 재질 선정 고려
# * 어깨 들처 매기 : 허리와 shoulder 지지대가 어깨 위로 올라오고 두 손으로 바나나를 완전히 들어 올리는 경우, 들처 매어도 지지대 간섭이 없도록 어깨 아래 버전
# * 방수 필요 (강을 건너는 경우) : 허리 이상 잠기는 경우가 많아 주요 구동부는 팔에 위치하되 허리쪽은 방수 또는 물에 저항성 높게 설계
# * 저가 : 100 불 버전? (가격대 별, actuator 동력 별 라인업 구축)
# * 허리로 하중 분산 필요 : 기본 설계 참조

# %% [markdown]
# ## ShouldX 제품 주목
# https://www.youtube.com/watch?v=BRsSMNmu7FE
#
# #### 동영상 내용 소개 (발표자 : SuitX COO)
#
# * 인간 공학 & 로보틱스 lab (UC 버클리 대학 교수 연구진)
# * 2010 년부터 시작, 2014 년 기업과 협업
# * 의료 & 산업계 TWO SIDES 로 진행
# * 산업용 shoulder X 는 한 팔당 6.8 kg 지탱
# * 어떤 움직임에도 방해받지 않고 자유롭게 팔을 움직임.
# * 90 % 이상의 노동자가 어깨, 허리, 무릎 등에 부상을 입은 이력이 있음.
# * 피곤을 덜 느끼게 하여 피로 누적을 없애고 노동 생산성 향상
# * 의료쪽은 2018 년 초에 FDA 규제 허가를 받으면 진입할 것이라고 하고 있고, 산업계는 2016 년부터
# * 의료 스켈레톤은 7,500 ~ 20,000 dollars 인데 가장 싼 것의 1/3 가격이라고 홍보 (2,500 달러)
# * 항공기 수화물 처리, 건설 작업자, 채굴 회사, 전력 회사, 항만 제조, lo 등 12 개 산업군을 타겟
# * 작업자의 생산성 향상 (일본의 경우 평균 건설 작업자 나이가 52 세), 부상 회복, 부상 방지
#     - 52 살인데 22 살처럼...
# * 3 세대 exo 버전이고 현장 voc 를 반영하여 개선
#
#
#
#
# ![](https://www.suitx.com/sites/default/files/shoulderX%20V3%20suitX.jpg)

# %% [markdown]
# ## 70 도 선택
#
# https://www.semanticscholar.org/paper/Design-and-Intended-Use-of-a-Passive-Actuation-for-Engelhoven-Kazerooni/66ab33d7273a49770dffaadba106e00109a452ca
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 90 도
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 110 도
# ![image.png](attachment:image.png)

# %% [markdown]
# ## shoulderX Actuator and Adjustment Location
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Actuator, FDB
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## backX, shoulderX, legX 를 모두 착용한 모습
#
# ![](https://i.pinimg.com/originals/7f/f8/a7/7ff8a782a823c19a0c19079ba4ff0ea1.jpg)

# %% [markdown]
# ## overhead exo
# ![](https://www.hilti.dk/medias/sys_master/images/h58/hcd/9532645015582.jpg)

# %%
import os

from pandas.api.types import is_string_dtype

import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.gridspec as gridspec
import matplotlib
from matplotlib.ticker import FuncFormatter
# %matplotlib inline

import chart_studio.plotly as py
import cufflinks as cf
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

import matplotlib.font_manager as fm  # 폰트 관련 용도
font_list = fm.findSystemFonts(fontpaths=None, fontext='ttf')

from matplotlib import rc
import platform
system = platform.system()
# %matplotlib inline
# %config inlineBackend.figure_format = 'retina'

from matplotlib.offsetbox import AnchoredText
from mpl_toolkits.axes_grid1 import make_axes_locatable
print("Matplotlib version", matplotlib.__version__)

mpl.rcParams['axes.unicode_minus'] = False
plt.style.use('seaborn')
sns.set(font_scale=1)

import folium
from folium import plugins
print(folium.__version__)

from pandas.plotting import autocorrelation_plot
from pandas.plotting import lag_plot
import datetime as dt

# 글씨 선명하게 출력하는 설정
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['figure.figsize'] = [8, 4] # [width, height] (inches) # 그림 크기의 확대
pd.options.display.max_rows = 100
pd.set_option('display.max_row', 500)
pd.set_option('display.max_columns', 100)

import warnings                   # 경고 무시
warnings.filterwarnings('ignore')
plt.rcParams['figure.dpi'] = 400 #high resolution
 
import json
from datetime import datetime

# helpful modules
import fuzzywuzzy
from fuzzywuzzy import process
import chardet

# for Box-cox Transformation
from scipy import stats

# for min_max scaling
from mlxtend.preprocessing import minmax_scaling

# set seed for reproducibility
np.random.seed(0)

import pandas_profiling
import missingno as msno

# 한글 폰트 설정
font_location = 'C:\\Users\\young min kim\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumGothic.ttf'
font_family = fm.FontProperties(fname = font_location).get_name()
matplotlib.rc('font', family=font_family)
plt.rcParams['font.family'] = font_family
plt.rc('axes', unicode_minus=False) # 마이너스 폰트 설정

from konlpy.tag import Kkma

# 가로로 넓게 쓰기
from IPython.core.display import display, HTML 
display(HTML("<style>.container { width:100% !important; }</style>"))

print("Setup Complete")
# Out:
# Matplotlib version 3.3.4
# 0.12.1
# <style>.container { width:100% !important; }</style>
# Setup Complete

# %% [markdown]
# # 따담

# %% [markdown]
# <img src="https://www.worldatlas.com/r/w960-q80/upload/46/cb/e1/shutterstock-252338818.jpg"
# style="width: 100%; height: 70%" align = "left">

# %% [markdown]
# # 전체 시장이 최소 1,000 억원 이상은 되어야 투입 할 가치가 있음.

# %% [markdown]
# ## 아이템 선정 고려 사항
#
# * DMT 경험이나 지식 활용할 수 있는 업종인가?
# * 인가나 허가를 받을 수 있는가? (수출 중심)
# * 실패의 위험이 작은가?
# * 자기 자본에 의한 창업이 가능한가?
# * 인적 네트워크를 갖추고 있는가?
# * 현재 사회 환경에 적합한가?
#
# ## 과일 선정
#
# 1. 시계열 기준 전 세계 생산량이 우상향 그래프를 그리는가?
# 2. 미래 식량 대용으로 손색이 없는가?
# 3. 수확 시 자동화가 얼마나 되어 있는가? (노동 집약적)
# 4. 중간 소매상들의 폭리가 있는가?

# %% [markdown]
# ### 1) 전 세계 과일 생산량 (1990 to 2019)
# ![](https://www.statista.com/graphic/1/262266/global-production-of-fresh-fruit.jpg)

# %% [markdown]
# ### 1) 전 세계 과일 생산 국가 (2019)
# 1) 중국 > (인도 - 브라질 - 미국 - 멕시코 - 터키 - 인도네시아) - 스페인 - 이란 - 이태리 순
# ![](https://cdn.statcdn.com/Statistic/275000/279164-blank-754.png)

# %% [markdown]
# ### 1) 미국 Price index (1982 - 1984 = 100)
# 1) 2007 년부터 2020 년까지 큰 변화 없음.
# ![](https://www.statista.com/graphic/1/262279/consumer-price-index-for-fresh-fruit-in-the-us.jpg)

# %%
df = pd.read_csv(r'E:\ML\dream\fruit.csv', encoding='cp949', parse_dates=True)
df

# %%
# pandas profiling 
# df.profile_report()

# %%
df.head(1)

# %%
df.info()

# %%
ax = sns.barplot(x='백만톤', y='종류', data=df)

# %%
df.head(1)

# %%
fruit = df.groupby('채집 방식')['백만톤']
sum_df = pd.DataFrame(fruit.sum())
sum_df

# %% [markdown]
# PPP(GDP) : Purchasing Power Parity
# 구매력평가 지수를 기반으로 계산한 GDP를 GDP(PPP)라 한다. 각국의 통화단위로 산출된 GDP를 단순히 달러로 환산해 비교하지 않고 각국의 물가수준을 함께 반영하는 것이다.
# 실제로 세계의 몇몇 나라들의 사례를 봤을 때 GDP도 낮고 GDP(PPP)도 그에 비해 낮은 경우, 그 국가의 평균적인 국민 생활상은 거의 멸망적인 수준이다.
# 예를 들어 아메리카 대륙 및 카리브 해 인근 섬 전체를 통틀어 거의 북한 수준으로 압도적인 가난함을 자랑하는 아이티의 경우 2017년 1인당 명목 GDP는 761$인데,
# 1인당 GDP(PPP)의 경우 1,810$로 GDP(PPP)/명목 GDP량이 2.3 정도이다.
#
# 이는 1인당 명목 GDP가 비슷한 나라들에 비하면 크게 낮은 수치로 남아시아의 최빈국 중 하나인 방글라데시의 1인당 명목 GDP는 1,532$이고
# 1인당 GDP(PPP)는 4,502$로 GDP(PPP)/명목 GDP량이 거의 3에 근접한다. 실제로 아이티의 체감 물가는 상당히 비싸다.
# 아이티 근로자들의 월급이 30$(한화로 약 ￦36,000) 수준에 불과한데, 자체적인 공산품 생산 설비가 워낙 열악해 비누 같은 생필품을 거의 대부분 이웃의 상대적으로 부국인
# 도미니카 공화국이나 해외에서 수입해 온다. 수입품의 경우 국제무역의 특성상 가난한 나라라고 해서 특별히 가격이 떨어지거나 하지 않는다.[5] 따라서 아이티인들은,
# 예를 들어 도미니카 공화국에서 수입한 생필품의 경우 도미니카 공화국 사람들과 같은 값을 주고 사용해야 한다.
# 도미니카 공화국에서 하루 일하고 번 돈으로 샴푸 10통을 살 수 있다고 하면, 아이티인들은 10일을 일해야 겨우 같은 샴푸 1통을 살 까 말까한 수준이다.
# 따라서 아이티인들은 지독한 임금체불과 폭력에도 불구하고 어떻게든 옆 나라인 도미니카 공화국에서 일을 하러 떠나고, 더러는 미국까지 흘러들어가기도 한다.
# 하지만 방글라데시의 경우, 절대 부유하다고는 할 수 없겠지만, 적어도 인력과 공장들 위주로 굴러가는 경제 덕분에 공산품이 그렇게 비싸지 않은 데다 주변국인 인도나 미얀마와의
# 소득 격차도 그다지 크지 않아 아이티만큼 살인적인 물가에 시달리지는 않는다. 방글라데시인 평균 월급이 5만 원 정도인 건 안 비밀
#
# 한가지더 쉽게 예시를 들자면 PPP를 자동차에 비유하자면 1인당 GDP(명목)가 낮지만 1인당 GDP(PPP)가 높은 경우는 양산형 대중차에 해당되고 1인당 GDP(명목)가 높고
# 1인당 GDP(PPP)가 낮은 경우는 프리미엄 브랜드라고 볼 수 있는데 둘의 공통점은 어떻게든 작동하고 굴러가지만 브랜드 가치의 차이로 인해 가격의 차이가 나는 정도라고 볼 수 있다.
# [6] 고로 1인당 GDP의 명목값이 높은 국가일수록 해당 국민의 실질적인 소비가 고급, 명품을 소비하는 성향이 있고 1인당 GDP의 PPP값만 높은 국가들의 경우 이냥저냥 생필품에
# 만족하고 살지만 수입 공산품은 비싸서 품질 낮고 싸구려인 물품을 쓸 가능성이 높다.[7]

# %% [markdown]
# 과일 소비 - 통계 및 사실
# 2021년 2월 10일
# 과일은 오랫동안 가공된 단것과 정제된 설탕에 대한 건강하고 자연스러운 대안으로 칭송되어 왔다.
# 미국의 과일과 채소 시장의 규모는 지난 10년 동안 전반적으로 증가해왔다. 2020년 현재, 신선한 과일의 판매는 미국 전체 생산 부문 매출의 약 절반을 차지한다.
# 그 해 신선과일의 소비자물가지수(CPI)는 평균 357.1로 전년의 360.1보다 하락했다.
#
# 1인당 소비량
# 일반적으로, 미국인들을 위한 식이요법 지침은 과일과 야채 섭취를 증가시킬 것을 권고한다. 그러나 최근의 통계는 과일 소비율이 약간 감소하는 것을 보여준다.
# 미국의 1인당 과일 소비량은 2000년 286파운드에서 2018년 276파운드로 감소했다. 그 중 미국 과일 섭취량의 대부분은 신선한 과일과 과일 주스의 형태였고,
# 통조림, 건조, 냉동 과일이 훨씬 적은 비율을 차지했다.
#
# 미국인들이 가장 좋아하는 과일
# 미국인들은 일상생활에서 다양한 과일을 소비한다. 2019년 조사에 따르면 바나나가 미국 소비자들 사이에서 가장 많이 구매되는 과일이었다.
# 사과, 딸기, 포도 등도 미국 소비자들이 많이 소비했다. 평균적으로 미국인들은 2019년에 1인당 27.4파운드의 신선한 바나나를 먹었는데, 이는 다른 어떤
# 과일보다도 훨씬 많은 양이다.

# %% [markdown]
# 2020-2025 중국 신선식품 전자상거래 시장규모 예측
# 이한마 출판사, 2020년 7월 2일
# 2025년 중국의 신선식품 전자상거래 시장 규모는 약 1조2700억 위안으로 2020년보다 3배 이상 커질 것으로 예측됐다.
# 중국 신선식품 전자상거래의 GMV는 2019년 2890억 달러에 육박했다.
# 2020~2025년 중국 신선식품 전자상거래 시장규모 추정

# %% [markdown]
# ### 2) 미래 식량 대용으로 손색이 없는가?
#
# * 토마토 :
#   - 소스, 케첩, 페이스트
#   - 설탕과 곁들일 경우 비타민 B1 손실
#   - 통조림 / 건조 / 소스 등으로 유통
#   - 솔라닌 독성이 있어 주의
#
# * 바나나 :
#   - 간식, 각종 음식 재료
#   - 생식, 건조, 케이크, 파이 등
#   - 탄수화물 풍부, 인, 칼륨, 비타민 A, 비타민 C, 수용성 식이섬유 풍부
# * 수박
# * 사과
# * 자몽
# * 포도
# * 오렌지
# * 망고

# %% [markdown]
# ## 전세계 스마트 농업 시장 규모 (**중국** 을 잡아라.)
#
# ![](data:image/png;base64,...)
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSorjFs7oLICcLGhOrBXyIj8GcwPjAaAyj4JA&usqp=CAU)

# %% [markdown]
# ### 생산량 1 위 토마토
# * 토마토 : https://www.youtube.com/watch?v=mSHWPm5NSJ8
#   (케첩, 세척, 껍질 벗기기 등 모두 자동, 전세계 생산량 1 위 과일)
# * 한국에서는 과수원으로 과일 위주로 생산, 곁가지 치기 주의, 생산량이 많아 보이진 않음.
# * 호주에서 대규모로 하는 경우 장비 사용은 가능해 보임 : https://www.youtube.com/watch?v=89E9MUpsakQ
# * 한국의 방울 토마토도 과수원, 레일 등을 깔아서 손으로 수확 : https://www.youtube.com/watch?v=cyWQFyj3dvI
# * 전자동 식물 공장 : https://www.youtube.com/watch?v=rvDikcUy-Yo
# * 색깔에 따른 성숙도 구분 필요 (덜 익은 것은 식중독), 섭취 형태에 따른 수확법 분류 필요
# * 건강에 매우 좋은 과일 (의사들이 싫어함.)
#
# ### 토마토 생산국가
# ![세계 토마토 생산량](https://www.atlasbig.com/images/%EC%84%B8%EA%B3%84-%ED%86%A0%EB%A7%88%ED%86%A0-%EC%83%9D%EC%82%B0%EC%A7%80%EB%8F%84.png)

# %% [markdown]
# ### 생산량 2 위 바나나
# * 바나나 : 동남아등 아시아가 최대 생산지, 자동화 안 되어 있음. https://www.youtube.com/watch?v=k5M-i7NzPwA
#   (주요 생산국 저렴한 인건비 문제, 모양에 상처나면 안 되는 점 필수 고려 : https://www.youtube.com/watch?v=gjsbVgM27Do)
# * 규모가 작고 접근성이 안 좋은 곳에 많이 위치 : https://www.youtube.com/watch?v=RnTT6UDliqU
# * 무게가 상대적으로 무거움, 잘라야 할 가지가 두꺼운 편
# * 인도, 우간다, 중국, 필리핀 순으로 생산 (상대적 저 임금 국가들)
#
# ## 바나나 생산 국가
# ![세계 바나나 생산량](https://ko.actualitix.com/doc/maps/wld/ko-world-map-banana-producing-countries-by-country.jpg)
#
# ## 바나나 멸종의 전조 (곰팡이, 2011 년 기사)
# ![](https://image.chosun.com/sitedata/image/201312/18/2013121804000_0.jpg)

# %% [markdown]
# ### 생산량 3 위 수박
# * 수박 : https://www.youtube.com/watch?v=skUFdp1eLpU
# * 손으로 대부분 옮김, 충격에 약하고 취급에 주의가 필요한 점 필수 고려 : https://www.youtube.com/watch?v=iYJblg5cxZ8
# * 수확만 손으로 하고 적재는 레일 활용 : https://www.youtube.com/watch?v=1xWXqJcli5Y, https://www.youtube.com/watch?v=4wOSM6o-PQI
# * 깨지기 쉬운 어려운 문제
#
# ## 수박 생산 국가
# ![전세계 수박 생산량](https://www.atlasbig.com/images/%EC%84%B8%EA%B3%84-%EC%88%98%EB%B0%95-%EC%83%9D%EC%82%B0%EC%A7%80%EB%8F%84.png)
#
# ## 국가별 수박 생산량
# ![](https://i.ytimg.com/vi/uWoPdU8ngc4/maxresdefault.jpg)

# %% [markdown]
# ### 생산량 4 위 사과
# * 사과 : 주스, 과일 자체로 섭취, 나무에서 따는 형태
# * 수작업 수확, 이동은 트랙터 등 활용, 주스 공장은 자동화 : https://www.youtube.com/watch?v=6cbJA4MWIBQ
# * 나무를 흔들어 떨어뜨리고 수확은 수작업 (주스용) : https://www.youtube.com/watch?v=ESDNKf3KgEI
# * 그대로 판매하는 사과는 사람이 손으로 수확, 분류나 세척, 포장은 자동화 : https://www.youtube.com/watch?v=ESDNKf3KgEI
# * 사과의 다양한 품종 : https://blog.naver.com/rfiennes/30105058645
# * **자동화된 기계 장비 사용** : https://www.youtube.com/watch?v=BIQN6Zxdr8s
# (ai, Abundant Robotics, 레이더 / 장애물 회피 / 컴퓨터 비전 / 사과 흡입 수확)
# * 색깔에 따른 성숙도 구분 기술 필요
#
# ## 전세계 사과 생산 국가
# ![전세계 사과 생산 국가](https://ko.actualitix.com/doc/maps/wld/ko-world-map-apple-producing-countries-by-country.jpg)
#
# ## 전세계 사과 생산량 (2011, faostats)
# ![](https://www.yara.kr/contentassets/5fabf56466b246cbb3481bdc2ca68dde/--2.png)

# %% [markdown]
# ### 생산량 5 위 자몽
# * 자몽 : 나무에서 따는 형태
# * 수작업 수확, 레일 등을 활용, 분류는 자동화 :  https://www.youtube.com/watch?v=g5yYgnTF2KI
# * 보통 주스로 섭취, 다른 약물 대사와 배출에 영향을 주므로 인구 고령화에는 맞지 않는 과일로 보임.
# * 껍질에 잔류 농약 파동이 있었음.
# * 미국, 남아공, 이스라엘 등이 최대 생산국
#
# ## 전세계 자몽 산업 동향
# ![전세계 자몽 산업 동향](data:image/jpeg;base64,...)
#
# ## 국가별 자몽 생산량
# ![](data:image/png;base64,...)

# %% [markdown]
# ### 생산량 6 위 포도 (포도주 용 포함 시 전 세계 과일 생산량 1 위)
# * 포도 : 나무에서 따는 형태, 손으로 수확
# * 일본의 농장 (유명하고 비쌈) : https://www.youtube.com/watch?v=J3SDDjP3AsU
# * 대규모 포도 농장, 주스용, **자동화된 기계 장비 사용** : https://www.youtube.com/watch?v=1I6AF24zfSM (장비 : NEW HOLLAND, 수확 / 채집)
# * 대규모 포도 농장, **자동화된 기계 장비 사용** : https://www.youtube.com/watch?v=WBmFH7fNxnA (장비 : PELLENC, 수확, 장비 구조를 조금 상세히 볼 수 있음.)
# * 수작업 포도 수확, 가지 분리, 세척, 와인은 자동화 : https://www.youtube.com/watch?v=NuCWb_rTsbE
# * 건강에 좋으면서 포도주로 인해 가장 대중적인 과일 (인구 고령화에 유리), 형태를 유지하려면 섬세한 수확 필요, 주스/와인 판매 형태는 기계 사용 중
#
# * 와인 생산 최저치 전망 (2017 년) : https://www.kati.net/board/exportNewsView.do?board_seq=25802&menu_dept2=35&menu_dept3=71
#
# ## 전세계 포도주 생산량
# ![포도주 생산량](http://www.sommeliertimes.com/news/photo/201610/2496_4048_4913.png)
#
# ## 전세계 포도 재배총론
# ![포도 재배총론](https://lh3.googleusercontent.com/proxy/otHdlloVGODmXZ-VyeNoxYIFVEGpCu7xI4c61-2g8ESKG36Xmeztlh-RBK8VdhIeitqaoiNU2CS4puWqJii88U2ISzZbzHeww-UrFQ)
#
# ## 2002 ~ 2010 년 국가별 포도 재배 면적
# ![](attachment:image.png)
#
# ## 와인 생산량 상위 10 개국
# ![](http://www.economyinsight.co.kr/news/photo/201803/3930_8530_1817.png)

# %% [markdown]
# ### 생산량 7 위 오렌지 (수확 기준으론 10 위 귤과 유사함.)
# * 오렌지 : 주스나 날 것으로 섭취
# * 사람을 태우는 기계, 수확은 사람이 손으로 하되 레일로 운반 : https://www.youtube.com/watch?v=8N0CJJ8uPX8
# * 나무 진동으로 떨어뜨리고 받아내는 기계 : https://www.youtube.com/watch?v=4_ikMEXjWHU
# * 수작업 수확 : https://www.youtube.com/watch?v=K1TjRSV1e_M
# * **자동화된 기계 장비 사용* : https://www.youtube.com/watch?v=Av17eM1Ruyo
#   (장비: Nelson harvesting, 감귤)
#   https://www.youtube.com/watch?v=IFpQqP1O6lA (장비: New Holland)
# * 상대적으로 단단한 외피, 인도, 브라질, 미국 캘리포니아, 남부 플로리다, 스페인, 호주, 남아공이 생산지
#
# ## 전세계 오렌지 생산 국가
# ![오렌지 생산 국가](data:image/jpeg;base64,...)
# ![](https://www.atlasbig.com/images/%EC%84%B8%EA%B3%84-%EC%98%A4%EB%A0%8C%EC%A7%80-%EC%83%9D%EC%82%B0%EC%A7%80%EB%8F%84.png)
#
# ![](https://lh3.googleusercontent.com/proxy/n9DYN1W7ucdaUltVjxH6srkxyRz4LVU7oMsuHZhQCJixWgfrzpa-3igr8SHh5wKIHrQK_FZnf4c5QLCCNckARqLDu77Xwl7j4J6W9g)

# %% [markdown]
# ### 생산량 8 위 망고
# * 망고 : 수작업, 이송은 레일 활용 https://www.youtube.com/watch?v=tjSADev3GYU
# * 세척 등은 자동화 : https://www.youtube.com/watch?v=wf3WqjSBqXM
# * 나무 위 수작업 : https://www.youtube.com/watch?v=2dpnY1oBrTE
# * **수확 로봇** (노동력 부족 대체, 유사 과일 수확 아이디어 참고되는 수준) : https://www.youtube.com/watch?v=3vAKuWUQb0I
# * 인도, 중국, 태국, 인도네시아, 파키스탄, 멕시코, 브라질 순 (중국 압도적)
# * 바나나, 파인애플, 망고 교역 현황 : https://repository.krei.re.kr/bitstream/2018.oak/22615/1/%ec%a3%bc%ec%9a%94%20%ec%97%b4%eb%8c%80%ea%b3%bc%ec%9d%bc%ec%9d%98%20%ec%84%b8%ea%b3%84%20%ec%83%9d%ec%82%b0%20%eb%b0%8f%20%ea%b5%90%ec%97%ad%20%ed%98%84%ed%99%a9:%20%eb%b0%94%eb%82%98%eb%82%98,%20%ed%8c%8c%ec%9d%b8%ec%95%a0%ed%94%8c,%20%eb%a7%9d%ea%b3%a0.pdf
#
# ## 전세계 망고 생산 국가
# ![](https://www.atlasbig.com/images/%EC%84%B8%EA%B3%84-%EB%A7%9D%EA%B3%A0%EC%99%80-%EA%B5%AC%EC%95%84%EB%B0%94-%EC%83%9D%EC%82%B0%EC%A7%80%EB%8F%84.png)

# %% [markdown]
# ###  멜론
# * 멜론 : 세척과 분류만 자동화 https://www.youtube.com/watch?v=6fF-SC3bH00

# %% [markdown]
# ### 파인애플
# * 파인애플 : https://www.youtube.com/watch?v=wWh_RLqcjaI

# %% [markdown]
# ### 복숭아
# * 복숭아 : https://www.youtube.com/watch?v=OhxyK_hyTHk

# %% [markdown]
# ### 자동 과일 수확 기계
# * **날으는 로봇** (FAR (flying autonomous robots), AI perception algorithms, 기동 및 균형, 로봇 정보 탭으로 리포팅) :
# https://www.youtube.com/watch?v=6olybtRPdwg
# * 여러 종류의 로봇 아키텍쳐 (컴퓨터 비전, 분류, Flying, 드론) : https://www.youtube.com/watch?v=bpa1iiJmR3Q
# * 수 작업 보조용도 (사과, 귤, 자두, 밤 등) : https://www.youtube.com/watch?v=7Uhtuluydds
# * 열매 따는 로봇 (SWEEPER ROBOT, AI, 자율 이동 박스 운송 연구 중, 23 년 이후 출시 추정) : https://www.youtube.com/watch?v=4szyNJjv-fo
# * 딸기 따는 로봇 (Agrobot, 24 개 팔, 농장용 로봇 시스템, 컴퓨터 비전, 하우스 내 적용, 딥러닝, Lidar 이용한 자율 주행 가능 ) : https://www.youtube.com/watch?v=eABA3Dw5ADQ
# * 딸기 따른 로봇 (올레팜, 느린 속도가 문제로 보임.) : https://www.youtube.com/watch?v=4AQ2Ic1WnOA
# * 미래형 AI 농업 (스마트팜, 온도, 습도, CO2 배출 등 조절하여 생산성 향상, 물/비료 자동 분사, 스마트폰 원격 조작, 매년 2 배 이상 증가) :
# https://www.youtube.com/watch?v=CrDI_c35wkQ
# * 방울 토마토 따는 로봇 (Root ai, 정교한 움직임, 컴퓨터 비전, 집게 형식, 실내 농업은 재배 환경 제어로 생산성 20 % 정도 올리고 물 소비는
# 90 % 줄임) : https://www.youtube.com/watch?v=MxfVX-aXtBA
# * 한국 농사 인구 감소에 따른 로봇, IT 기술 응용 : https://www.youtube.com/watch?v=de4Fyjzpv4c
# * 여러가지 AI 로봇 (컴퓨터 비전 기술, 로봇 제어) : https://www.youtube.com/watch?v=FxuVzVJ_xRE
# * 물에 뜨는 Cranberry 수확 : https://www.youtube.com/watch?v=0OXk0tUVbg8
# * 7 가지 로봇 : https://www.youtube.com/watch?v=jvbIvtwEDTY

# %% [markdown]
# ### 어떤 제조사들이 있는가?
# * Abundant Robotics
#     - 컴퓨터 하드웨어, 1 ~ 10 명, 비상장 기업, 2015 년
#     - 로보틱스, 농업, 기계, AI, ML
# * AgroConcept - NEW HOLLAND Agriculture
#     - 기계, 51 ~ 200 명, 비상장 기업, 2015 년
#     - 농업, 구축, 트랙터 & 조합, 서비스 & 수리 및 스마트 농업
# * PELLENC
#     - 1 억 7 천만불 (2021 년, 그룹)
#     - 전기전자, 기계, 산업 공학
# * Nelson harvesting
#     - 29.3 만불 (2021 년)
# * Mashable
# * Sweeper
# * Agrobot
# * FF Robotics
# * SIFR
# * ROOT AI
# * ecorobotix

# %% [markdown]
# ## 국내 과수 총 생산
# ![](https://cdn.seogwipo.co.kr/news/photo/201802/146106_111227_3327.jpg)

# %% [markdown]
# ## 목표 분리
#
# 1) 특정 과일군을 수확하는 농기계
# 2) 인간을 도와 수확 생산성을 높이는 장치

# %% [markdown]
# ### 세계 인구의 고령화 (65 세 이상 인구, 2010 ~ 2050 년)
# ![](https://mordorintelligence.com/images_db/RD_Images/1559817010447_info.png)

# %% [markdown]
# ## Wearable robotics? (Exoskeletons)
# * 현대 그룹, 상향 작업용 착용 로봇 VEX (No battery~!!) : 1,300 만원 수준 (11,700 달러 수준, 경쟁사 대비 30 % 저렴)
#
# ![현대 그룹, 상향 작업용 착용 로봇 VEX](https://tech.hyundaimotorgroup.com/kr/wp-content/uploads/sites/2/2019/09/cropped-KV-3-1440x810.jpg)
#
# ![](https://img.directindustry.com/images_di/projects/videos-thumbnails/107833-8341.jpg)

# %% [markdown]
# * 카와사키, Power Assist Suit (4 개의 battery, 리튬 배터리, 슈트 자체 무게 느낄 수 없도록 설계)
#
# ![](https://techcrunch.com/wp-content/uploads/2011/09/kawasaki_0921.jpg?w=1390&crop=1)
# ![](https://techcrunch.com/wp-content/uploads/2011/09/picture-15.png)
# 동영상 : https://youtu.be/SPbjh9aDNW0

# %% [markdown]
# * 의료 목적 재활용 (미국 뇌졸중 협회)
#
# ![](https://www.thumbayrehab.com/wp-content/uploads/2019/05/WEARABLE-ROBOTIC-EXOSKELETON_.jpg)

# %% [markdown]
# ## wearable robotics industry growth rate

# %% [markdown]
# ### Global market insights : Exoskeleton Market
# * 2.2 억불 (2,474 억, 2018 년) 에서 35 억불 (3조 9천억, 2026 년), 년 평균 성장률 41.5 % 이상 예측 이상 예측
#
# ![](https://www.gminsights.com/assets/img/exoskeleton-market-pressrelease.png)

# %% [markdown]
# ![](https://www.psmarketresearch.com/img/Global-Exoskeleton-Market.jpg)

# %% [markdown]
# ![](https://s3.mordorintelligence.com/exoskeleton-market/exoskeleton-market_Picture1233.png)

# %% [markdown]
# ## robosuits.it
# https://www.robosuits.it/
# ![](https://www.robosuits.it/images/european-market-grapho.jpg)

# %% [markdown]
# * 가장 효율적인 노동자는 하루를 일거리로 가득 채우지 않으며 편안함과 느긋함에 둘러싸여 일한다.
#   일을 많이 하는 사람은 열심히 하지 않는다.

# %% [markdown]
# * 실패는 오래 가지 않는다. 젊을 때는 해고 사유였던 일로, 늙어서는 평생 공로상을 받을 수도 있다.
#   <대부, 지옥의 묵시록 감독 프랜시스 코폴라>

# %% [markdown]
# * 열정은 삶과 아무 연관이 없다. 직업 만족의 가장 큰 조건은 "가슴이 뛰느냐" 가 아니라 "정신이 참여할 수 있느냐" 이다.
#   <옥스퍼드 링컨 칼리지 철학 교수 윌 맥어스킬>

# %% [markdown]
# * 아이디어에서 글이 출발하는 게 아니다. 막상 글 쓰기 시작하면 아무 생각도 나지 않는다. 하지만 정말로 글을 일단 쓰기 시작하면 생각이 거기서 나온다.
#   정말 큰 깨달음이다.
#   <와이어드 창립자 케빈 빌리>

# %% [markdown]
# * 이것 저것 제약이 많았던 상황이 오히려 내겐 자유였다. 한계 안에서 완전한 자유를 느꼈다. 다 갖춰진 상태에서 성공이 나오는 것은 절대 아니다.
#   <영화감독, 각본, 제자, 촬영감독, 편집, 뮤지션 로버트 로드리게즈>

# %% [markdown]
# * 우리 회사가 살아남을 수 있던 이유는 세 가지다.
#     - 돈도 없고
#     - 기술도 없고
#     - 계획도 없었기 때문
# * 그래서 모두가 최대한 신중한 자세로 돈 없어도 실현 가능한 아이디어를 최대한 짜내려 노력 했기 때문이다.
#    <알리바바, 마윈>

# %% [markdown]
# ![](https://patents.patsnap.com/images/US/98/89/55/4/US09889554-20180213-D00000.png)

# %% [markdown]
# ![](https://www.degruyter.com/document/doi/10.1515/cdbme-2020-2001/asset/graphic/j_cdbme-2020-2001_fig_001.jpg)

# %% [markdown]
# ![](https://uspto.report/patent/grant/10596059/US10596059-20200324-D00000.png)

# %% [markdown]
# ![](https://uspto.report/patent/grant/10569413/US10569413-20200225-D00000.png)

# %% [markdown]
# 참조 주소 : http://www.soheil-sadeqi.com/exoskeleton#parallelexoskeleton1
#
# ![](https://images.squarespace-cdn.com/content/v1/55639e11e4b0576ead6fd140/1461954028635-9NDV1ST8NOESG0H4KX78/ke17ZwdGBToddI8pDm48kE81M35mphWz67U4gnkDg857gQa3H78H3Y0txjaiv_0fMd-BlcF4RpG1NxMpmwFlTwkuSX2zzvHL0N8sDQZXgJvrfhFEOnb3zfIgwthTN8YWZGjoBKy3azqku80C789l0kMlYkjvFlctRdmAM11rxFQZcxXeUx-UjTTH29SjdN_8OJDMUeFzT06N_0LSkVFdgw/image-asset.jpeg)

# %% [markdown]
# # Tools of Titans
#
# #### 남들보다 뛰어난 감각을 동원하라
#     - 첫번째 버전은 언제나 실패작 : 아이디어와 창의성의 진보는 백지 위에 처음 밑그림을 그리는 순간과 그렸던 밑그림을 지우고 그 위에 다시 그리는 순간 사이에 존재함. ("아무것도 그리지 않은 상태에서 완성되는 것, 진부해지지 않으려면 그리지 않아야 한다." 이 말을 이해 할 수 있겠는가?)
#
# #### 창의력은 창의적 해석력, 독창성은 독창적 해석력
#     - 완전히 새로운 것을 만들어 낼 기회는 극히 드물다.
#     - 남들보다 더 잘 해석할 수 있는 감각을 선택하는 일이 중요한 이유
#     - 창의적 사람들은 끊임없이 "보는 법" 을 배우고 훈련하는 것 뿐
#
# #### 실패란 완전히 실패하는 것, 대체 불가능한 사명 찾기
#     - 실패는 하나의 사유로 되는 것이 아니다. 존재하는 모든 이유때문에 실패하고 완전한 실패만이 계속되는 실패를 멈추고 백지에서 다시 시작하게 한다.
#     - 그래서 실패는 오래가지 않는다.
#     - 트렌드는 중요하지 않다. 미래의 삶에 가장 중요한 역할을 하는 것은 '사명감' 이다.
#     - 다른 사람들이 엄두도 내지 못한 문제를 찾아 해결하는 노력이 사명감
#     - 지금 떠올리는 문제 중 아직 아무도 해결하지 못한 것은 무엇인가?
#     - 독점 (소규모 시장에서 큰 폭의 점유율로 시작?), 비밀 (다른 사람은 미처 알아차리지 못한 독특한 기회 발견?), 유통 (고객에게 전달은?)
#
# #### 10 개 아이디어 생각이 안나면 20 개를 생각해라
#     - 아이디어는 무조건 많아야 되고 실행 플랜은 무조건 간단해야 함.
#     - 많은 것을 떠올리고 많은 것을 버려라.
#     - 당신이 할 수 있는 가장 미친 짓 리스트를 만들어라. 사람들은 당신의 진지하고 뛰어난 생각보다 미친 아이디어를 더 좋아할 가능성이 높다.
#
# #### 아이디어 만들기 연습
#     - 새롭게 만들 수 있는 낡은 아이디어
#     - 직접 발명할 수 있는 우스꽝스런 물건
#     - 구글, 아마존, 트위터 등을 이용한 사업 아이디어
#     - 촬영 할 수 있는 팟캐스트나 동영상 아이디어
#     - 중간 상인을 없앨 수 있는 사업
#     - 다른 사람들이 진리라고 떠들지만 나는 동의하지 않는 물건이나 가치관 (브랜드, 대학 진학, 내집 마련, 메이저리그, 스마트 폰 등)
#
# #### 수준 높은 모임에서 다양한 토론 (dream TF 모임이 그리 되길 바람.)

# %% [markdown]
# ## INSIGHT (MIT)
#
# #### 본질을 보기 어려운 정보 과잉의 시대에 살고 있다.
# #### 그래서, 성과는 결국 통찰에 달려 있다.
# #### 사람은 의외로 깊이 생각하지 않고, 뇌는 습관대로 생각하므로 아래 9 가지 통찰을 방해하는 요소를 인지하고 있자.
#     - 현상의 반대를 결론으로 삼는 습관
#         1) 피곤하다 -> 휴가 쓰자
#         2) 제품이 잘 안팔린다 -> 어떻게든 팔아야 한다.
#     - 일반론에 만족하는 습관
#         1) 살이 쪘다 -> 식사량을 줄이자
#     - 프레임워크에 의존하는 습관
#         1) SWOT (강점, 약점, 기회, 위협 매트릭스) 분석 후 생각을 그만하는 것
#            => 작업 자체에 성취감을 느끼고 깊이 생각했다는 착각에 빠짐.
#     - 카테고리에 빠지는 습관
#         1) 그 사람 논리적이야 -> 이공계 출신일껄
#         2) 요즘 A 사 실적이 별로래 -> 제조업이니 어쩔 수 없지
#            (그 와중에도 잘 나가는 제조업이 있다.)
#     - 키워드에서 생각 멈추는 습관
#         1) 차별화하자, 경쟁 우위 확보, 고객만족도 향상 등 키워드 하나로 정리하면
#            구체성이 사라짐.
#     - 초기 가설을 고집하는 습관
#         1) 가설은 본래 새로운 정보나 발견에 의해 진화하는데 초기 가설만 고집하면
#            진화가 원천 차단됨.
#         2) 한 지역에서 성공한 사례도 다른 지역에선 가설이 달라질 수 있다.
#         2) 토론이나 회의 시 "다만", "하지만", "그러나" 등의 말을 많이 쓰는 증상을 보임.
#     - 생각의 입구에 머무는 습관
#         1) 정보 수집 시 너무 몰입해 목적을 잊고 그것 자체에 집중하는 습관
#            (현상의 표층에서 머무를 수 밖에)
#         2) 분석을 위한 분석
#     - 프로세스로만 돌리려는 습관
#         1) 고객이 정말 원하는 것은 무엇인가?
#            -> 앙케이트 조사를 하면 고객이 원하는 것을 알 수 있습니다.
#            (프로세스에 의존한 답변)
#         2) 1) 번의 옳은 대답은 "고객이 정말로 원하는 것은 대응의 내용이 아니라
#            신속한 대응이라 생각합니다. 그것은 고객 앙케이트를 통해 명확해 질 것입니다."
#            와 같이 자신의 머리로 해결책을 제시하는 대답임.
#     - 주체성을 잃어버리는 습관
#         1) 다른 사람의 머리에 의지하는 습관
#             * A 제품이 안 팔리는 이유는 고객이 이미 질렸기 때문이라 생각합니다.
#             * 내 생각은 그렇지 않네. 경쟁사 B 제품은 시장 점유율을 크게 확대하고 있지 않나?
#             * 그렇다면 타사의 C 제품도 고전을 면치 못하고 있겠군요.
#               (이 답변은 잘못된 예시임.)

# %% [markdown]
# ## SYSTEM DYNAMICS (MIT)
#
# #### 사물의 본질은 모델 + 다이너미즘의 결합
#     - 모델 : 현상을 만들어 내는 구성 요소와 그 구성 요소들 사이의 상호관계성
#     - 다이너미즘 : 장기적 관점에서 모델이 만들어 내는 움직임
